# %%
from google.colab import drive
drive.mount('/content/gdrive')
path = 'path-to-set'

# %%
# !pip install -r /yolov5/requirements.txt

# %% [markdown]
# Check config

# %%
# !cat gdrive/MyDrive/praca-inzynierska/yolov5/trafficsigns.yaml

# %% [markdown]
# Train with yolov5l using GPU

# %%
# !python yolov5/train.py --img 640 --batch 32 --epochs 100 --data yolov5/trafficsigns.yaml --weights yolov5l.pt --device 0 --cache

# %% [markdown]
# Test

# %%
# !python yolov5/detect.py --weights yolov5/runs/train/exp13/weights/best.pt --img 640 --conf 0.5 --source img1.jpg
